# %% [markdown]
# ###  Practica 8

# %% [markdown]
# Elaborado por:
# **Edgar Cruz Salas** - **220219**

# %% [markdown]
# ### PASO 1: Librerias y configuraciones

# %%
# %%time

# Instalación de librerías necesarias:
from gc import collect  # Recolección de basura para liberar memoria
from warnings import filterwarnings  # Manejo de mensajes de advertencia

import re  # Expresiones regulares

import numpy as np  # Álgebra lineal
import pandas as pd  # Procesamiento de datos, lectura de archivos CSV, etc.
from scipy import stats  # Funciones estadísticas

from itertools import cycle, combinations  # Generación de combinaciones y ciclos

import matplotlib.pyplot as plt  # Visualización de datos
from matplotlib.ticker import FuncFormatter  # Formato personalizado para marcas en ejes
from matplotlib.ticker import FormatStrFormatter  # Formateo de marcas con cadenas
from mpl_toolkits.mplot3d import Axes3D  # Módulo para gráficas en 3D
from matplotlib.colors import ListedColormap  # Mapa de colores para gráficos de dispersión
import seaborn as sns  # Visualización estadística de datos
from wordcloud import WordCloud  # Nube de palabras para visualizar datos textuales

from io import StringIO  # Entrada/salida en memoria (usado para redirigir texto)

filterwarnings('ignore')  # Ignorar mensajes de advertencia
from IPython.display import display, HTML, display_html, clear_output  # Mostrar contenido HTML en Jupyter

# Limpia salida previa y recolectar basura
clear_output()
print()
collect()
# Out:
# CPU times: total: 109 ms
# Wall time: 103 ms
# 0

# %%
# Establecer el estilo de gráficos a 'fivethirtyeight'
class color:
    GRAY = '\033[90m'
    LIGHT_BLUE = '\033[94m'
    BLUE = '\033[94m'
    CYAN = '\033[96m'
    BOLD = '\033[1m'
    RED = '\033[91m'
    END = '\033[0m'
    UNDERLINE = '\033[4m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    MAGENTA = '\033[95m'
    WHITE = '\033[97m'
    BLACK = '\033[30m'
    LIGHT_RED = '\033[91m'
    LIGHT_GREEN = '\033[92m'
    LIGHT_YELLOW = '\033[93m'
    LIGHT_BLUE = '\033[94m'
    LIGHT_MAGENTA = '\033[95m'
    LIGHT_CYAN = '\033[96m'
    LIGHT_WHITE = '\033[97m'
    RESET = '\033[0m'

# Definir propiedades globales de estilo (por ejemplo, para tablas HTML)
global_style = {
    "background-color": "#ff4d4d",  # Fondo rojo suave
    "color": "#e6e6ff",             # Texto claro
    "border": "1.5px solid black",  # Borde negro
    "font-weight": "bold"           # Texto en negritas
}

# Aplicar estilo visual a gráficos
plt.style.use("fivethirtyeight")
sns.set(rc={"figure.figsize": (10, 10)})

# Mensaje de confirmación en consola (con color verde)
print(f"{color.GREEN}¡Librerías configuradas exitosamente!{color.END}")
# Out:
# ¡Librerías configuradas exitosamente!

# %% [markdown]
# ### PASO 2: Carga del dataset

# %%
# %%time

# Manejo de errores al cargar el conjunto de datos con Pandas read_csv

try:
    # Intentar leer el conjunto de datos
    df = pd.read_csv('salaries.csv')
    print(f"{color.GREEN}Dataset cargado exitosamente.{color.END}")
    
except FileNotFoundError:
    # Manejar el error si el archivo no existe
    print(f"{color.RED}Error: Archivo no encontrado. Verifica la ruta del archivo.{color.END}")

except Exception as e:
    # Manejar cualquier otro tipo de excepción
    print(f"{color.RED}Ocurrió un error al cargar el conjunto de datos: {e}{color.END}")

# Imprimir texto en azul (vacío por ahora, pero mantiene estilo)
print(color.BLUE)
collect()
# Out:
# Dataset cargado exitosamente.
#
# CPU times: total: 141 ms
# Wall time: 148 ms
# 5

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\52746\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\52746\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\52746\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\52746\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\52746\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\52746\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# ### PASO 3: Resumen de atributos

# %%
def display_dataframe_with_custom_header(df, show_head=False):
    # Definir propiedades globales de estilo
    global_style = {
        "background-color": "#2e3440",
        "color": "#FFFF00",
        "border": "1.5px solid black",
        "font-weight": "bold",
        "font-family": "'Courier New', Courier, monospace"  # Usar fuente monoespaciada para vista en tabla
    }

    # Texto de encabezado personalizado con fuente "Poetsen One" y efecto de onda
    header_text = """
    <h2 style='color: #FF5733; font-weight: bold; font-family: "Poetsen One", sans-serif;
                animation: wave 1.5s infinite;'>
        D<span style="color: #FFFF00;">A</span>T<span style="color: #FFFF00;">A</span>FRAME 
        {frame_type} 
    </h2><br>

    <style>
    @keyframes wave {{
        0% {{ transform: rotate(-2deg); }}
        50% {{ transform: rotate(2deg); }}
        100% {{ transform: rotate(-2deg); }}
    }}
    </style>
    """

    # Determinar el tipo de visualización
    frame_type = "HEAD" if show_head else "INFORMATION"
    header_text = header_text.format(frame_type=frame_type)

    if show_head:
        # Obtener las primeras filas del DataFrame
        df_to_display = df.head()

        # Convertir el DataFrame a tabla HTML
        df_html = df_to_display.to_html(index=False, classes='styled-table', header=True)

        # Aplicar estilos a la tabla
        styled_df = f'''
        <style>
        .styled-table {{
            border-collapse: collapse;
            margin: 25px 0;
            font-size: 0.9em;
            font-family: sans-serif;
            min-width: 400px;
            box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
        }}
        .styled-table thead th {{
            padding-top: 12px;
            padding-bottom: 12px;
            text-align: left;
            background-color: #2e3440;
            color: ##81a1c1;
            border: 1px solid #ddd;
            font-weight: bold;
        }}
        .styled-table tbody td {{
            padding: 12px 15px;
            border: 1px solid #ddd;
        }}

        .wave-animation {{
            animation: wave 1.5s infinite;
        }}
        </style>
        {header_text}
        {df_html}
        '''
    else:
        # Redirigir la salida de df.info() a un string
        info_output = StringIO()
        with pd.option_context('display.max_info_rows', 1000, 'display.max_info_columns', 1000):
            df.info(buf=info_output)

        # Obtener la información como cadena
        info_string = info_output.getvalue()

        # Aplicar estilos al bloque de texto
        styled_df = f'''
        {header_text}
        <pre style="{";".join([f"{key}: {value}" for key, value in global_style.items()])};">
        {info_string}
        </pre>
        '''

    # Incluir fuente personalizada desde Google Fonts
    google_fonts_link = "<link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>"

    # Contenido HTML final
    html_content = f'''
    <!DOCTYPE html>
    <html>
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>Información del DataFrame</title>
        {google_fonts_link}
    </head>
    <body>
        {styled_df}
    </body>
    </html>
    '''

    # Mostrar contenido en Jupyter Notebook
    display(HTML(html_content))

# %%
display_dataframe_with_custom_header(df) 
display_dataframe_with_custom_header(df, show_head=True)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <title>Información del DataFrame</title>
#         <link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>
#     </head>
#     <body>
#
#
#     <h2 style='color: #FF5733; font-weight: bold; font-family: "Poetsen One", sans-serif;
#                 animation: wave 1.5s infinite;'>
#         D<span style="color: #FFFF00;">A</span>T<span style="color: #FFFF00;">A</span>FRAME
#         INFORMATION
#     </h2><br>
#
#     <style>
#     @keyframes wave {
#         0% { transform: rotate(-2deg); }
#         50% { transform: rotate(2deg); }
#         100% { transform: rotate(-2deg); }
#     }
#     </style>
#
#         <pre style="background-color: #2e3440;color: #FFFF00;border: 1.5px solid black;font-weight: bold;font-family: 'Courier New', Courier, monospace;">
#         <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73167 entries, 0 to 73166
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   work_year           float64
#  1   experience_level    object
#  2   employment_type     object
#  3   job_title           object
#  4   salary              float64
#  5   salary_currency     object
#  6   salary_in_usd       float64
#  7   employee_residence  object
#  8   remote_ratio        float64
#  9   company_location    object
#  10  company_size        object
# dtypes: float64(4), object(7)
# memory usage: 6.1+ MB
#
#         </pre>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <title>Información del DataFrame</title>
#         <link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>
#     </head>
#     <body>
#
#         <style>
#         .styled-table {
#             border-collapse: collapse;
#             margin: 25px 0;
#             font-size: 0.9em;
#             font-family: sans-serif;
#             min-width: 400px;
#             box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#         }
#         .styled-table thead th {
#             padding-top: 12px;
#             padding-bottom: 12px;
#             text-align: left;
#             background-color: #2e3440;
#             color: ##81a1c1;
#             border: 1px solid #ddd;
#             font-weight: bold;
#         }
#         .styled-table tbody td {
#             padding: 12px 15px;
#             border: 1px solid #ddd;
#         }
#
#         .wave-animation {
#             animation: wave 1.5s infinite;
#         }
#         </style>
#
#     <h2 style='color: #FF5733; font-weight: bold; font-family: "Poetsen One", sans-serif;
#                 animation: wave 1.5s infinite;'>
#         D<span style="color: #FFFF00;">A</span>T<span style="color: #FFFF00;">A</span>FRAME
#         HEAD
#     </h2><br>
#
#     <style>
#     @keyframes wave {
#         0% { transform: rotate(-2deg); }
#         50% { transform: rotate(2deg); }
#         100% { transform: rotate(-2deg); }
#     }
#     </style>
#
#         <table border="1" class="dataframe styled-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>work_year</th>
#       <th>experience_level</th>
#       <th>employment_type</th>
#       <th>job_title</th>
#       <th>salary</th>
#       <th>salary_currency</th>
#       <th>salary_in_usd</th>
#       <th>employee_residence</th>
#       <th>remote_ratio</th>
#       <th>company_location</th>
#       <th>company_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2025.0</td>
#       <td>SE</td>
#       <td>FT</td>
#       <td>Data Product Owner</td>
#       <td>170000.0</td>
#       <td>USD</td>
#       <td>170000.0</td>
#       <td>US</td>
#       <td>0.0</td>
#       <td>US</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#
#     </body>
#     </html>

# %% [markdown]
# ### PASO 4: Manejo de valores perdidos

# %%
def plot_missing_values_heatmap(df):
    # Calcular la suma de valores faltantes excluyendo la primera columna
    missing_values_sum = df.isna().iloc[:, 1:].sum()

    # Crear una paleta de colores personalizada
    custom_palette = sns.color_palette("colorblind", as_cmap=True)  # Ejemplo de paleta, puedes elegir otra si lo deseas

    # Crear el gráfico de mapa de calor
    plt.figure(figsize=(22, 4), facecolor='silver')
    ax = sns.heatmap(
        missing_values_sum.to_frame(name='').T.rename(columns=lambda x: x.replace('_', ' ').title()), 
        cmap=custom_palette,
        annot=True,
        fmt='0.0f',
        annot_kws={"fontsize":30, "fontweight": "bold"},  # Ajustar el tamaño y peso de la fuente para las anotaciones
        linecolor='black',
        linewidth=2  # Establecer el color y grosor del borde
    )

    # Establecer el título y ajustar el tamaño de fuente
    plt.title('Count of Missing Values', pad=20, fontsize=18, color='#FF9734', fontname='Calibri', fontweight='bold')

    # Rotar las etiquetas del eje X
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=15, fontweight='bold')

    # Ajustar el tamaño y peso de la fuente de las etiquetas del eje Y
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=15, fontweight='bold')

    # Mostrar el gráfico
    plt.show()

# %%
plot_missing_values_heatmap(df)

# %% [markdown]
# ### PASO 5: Manejo de valores duplicados

# %%
# Verificar la cantidad de filas duplicadas en el DataFrame
valores_duplicados = df.duplicated().sum()
print(f"\033[94mEl conjunto de datos contiene \033[1m\033[91m{valores_duplicados}\033[0m \033[94mvalores duplicados.\033[0m")

# Eliminar filas duplicadas
df_sin_duplicados = df.drop_duplicates()
# Out:
# El conjunto de datos contiene 39134 valores duplicados.

# %%
def apply_duplicated_styling(df):
    
    # Definir una función para aplicar tamaño de fuente y color a los valores
    def apply_style(value):
        if value:
            return 'font-size: 20px; color: red'
        else:
            return 'font-size: 20px; color: green'

    # Definir una función para aplicar tamaño de fuente a los nombres de columna
    def apply_column_name_style(value):
        return 'font-size: 20px'

    # Transponer el DataFrame y verificar valores duplicados en las filas (que originalmente eran columnas)
    column_duplicates = df.T.duplicated()

    # Aplicar estilo al DataFrame que contiene la iformación de columnas duplicadas
    styled_column_duplicates = column_duplicates.to_frame().style.applymap(apply_style).background_gradient(axis=0)

    # Aplicar estilo a los nombres de columna
    styled_column_duplicates.set_table_styles([{'selector': 'th', 'props': [('font-size', '20px')]}])

    return styled_column_duplicates

# %%
styled_df = apply_duplicated_styling(df)
styled_df
# Out:
# <style type="text/css">
# #T_fa925 th {
#   font-size: 20px;
# }
# #T_fa925_row0_col0, #T_fa925_row1_col0, #T_fa925_row2_col0, #T_fa925_row3_col0, #T_fa925_row4_col0, #T_fa925_row5_col0, #T_fa925_row6_col0, #T_fa925_row7_col0, #T_fa925_row8_col0, #T_fa925_row9_col0, #T_fa925_row10_col0 {
#   font-size: 20px;
#   color: green;
# }
# </style>
# <table id="T_fa925">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa925_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa925_level0_row0" class="row_heading level0 row0" >work_year</th>
#       <td id="T_fa925_row0_col0" class="data row0 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row1" class="row_heading level0 row1" >experience_level</th>
#       <td id="T_fa925_row1_col0" class="data row1 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row2" class="row_heading level0 row2" >employment_type</th>
#       <td id="T_fa925_row2_col0" class="data row2 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row3" class="row_heading level0 row3" >job_title</th>
#       <td id="T_fa925_row3_col0" class="data row3 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row4" class="row_heading level0 row4" >salary</th>
#       <td id="T_fa925_row4_col0" class="data row4 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row5" class="row_heading level0 row5" >salary_currency</th>
#       <td id="T_fa925_row5_col0" class="data row5 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row6" class="row_heading level0 row6" >salary_in_usd</th>
#       <td id="T_fa925_row6_col0" class="data row6 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row7" class="row_heading level0 row7" >employee_residence</th>
#       <td id="T_fa925_row7_col0" class="data row7 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row8" class="row_heading level0 row8" >remote_ratio</th>
#       <td id="T_fa925_row8_col0" class="data row8 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row9" class="row_heading level0 row9" >company_location</th>
#       <td id="T_fa925_row9_col0" class="data row9 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa925_level0_row10" class="row_heading level0 row10" >company_size</th>
#       <td id="T_fa925_row10_col0" class="data row10 col0" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### PASO 6: Datos estadisticos

# %%
def calculate_statistics(df, opacity=0.5, font_size='17px'):
    # Filtrar solo columnas numéricas
    numeric_df = df.select_dtypes(include=['number'])
    
    stat = pd.DataFrame()  # Inicializar un DataFrame vacío

    # Medidas de tendencia central
    stat['Mean'] = numeric_df.mean()       # Media de todas las columnas
    stat['Median'] = numeric_df.median()   # Mediana de todas las columnas
    stat['Mode'] = numeric_df.mode().iloc[0]  # Moda de todas las columnas

    # Medidas de dispersión
    stat['Range'] = (numeric_df.max() - numeric_df.min())  # Rango
    stat['Stdev'] = numeric_df.std()       # Desviación estándar
    stat['Variance'] = numeric_df.var()    # Varianza

    # Rango intercuartílico (IQR)
    stat['IQR'] = [stats.iqr(numeric_df[i]) for i in numeric_df.columns]

    # Cuartiles
    stat['25%'] = numeric_df.quantile(q=0.25, axis=0)
    stat['50%'] = numeric_df.quantile(q=0.50, axis=0)
    stat['75%'] = numeric_df.quantile(q=0.75, axis=0)

    # Mínimos y máximos
    stat['Min'] = numeric_df.min()
    stat['Max'] = numeric_df.max()

    # Sesgo y curtosis
    stat['Skewness'] = numeric_df.skew()    # Asimetría
    stat['Kurtosis'] = numeric_df.kurt()    # Curtosis

    # Transponer el DataFrame para mejor presentación
    stat = stat.T

    # Aplicar formato flotante a dos decimales
    stat = stat.applymap('{:,.2f}'.format)

    # Aplicar color de fondo con transparencia
    styled_df = stat.style.apply(lambda x: [f'background: rgba(173, 216, 230, {opacity})' for val in x], axis=1)
    
    # Aplicar tamaño de fuente
    styled_df = styled_df.set_properties(**{'font-size': font_size})
    
    return styled_df

# %%
# Ejemplo de uso:
# DataFrame llamado 'df' y deseas establecer la opacidad a 0.4
stats_df = calculate_statistics(df, opacity=0.4, font_size='19px')
stats_df
# Out:
# <style type="text/css">
# #T_9a8e2_row0_col0, #T_9a8e2_row0_col1, #T_9a8e2_row0_col2, #T_9a8e2_row0_col3, #T_9a8e2_row1_col0, #T_9a8e2_row1_col1, #T_9a8e2_row1_col2, #T_9a8e2_row1_col3, #T_9a8e2_row2_col0, #T_9a8e2_row2_col1, #T_9a8e2_row2_col2, #T_9a8e2_row2_col3, #T_9a8e2_row3_col0, #T_9a8e2_row3_col1, #T_9a8e2_row3_col2, #T_9a8e2_row3_col3, #T_9a8e2_row4_col0, #T_9a8e2_row4_col1, #T_9a8e2_row4_col2, #T_9a8e2_row4_col3, #T_9a8e2_row5_col0, #T_9a8e2_row5_col1, #T_9a8e2_row5_col2, #T_9a8e2_row5_col3, #T_9a8e2_row6_col0, #T_9a8e2_row6_col1, #T_9a8e2_row6_col2, #T_9a8e2_row6_col3, #T_9a8e2_row7_col0, #T_9a8e2_row7_col1, #T_9a8e2_row7_col2, #T_9a8e2_row7_col3, #T_9a8e2_row8_col0, #T_9a8e2_row8_col1, #T_9a8e2_row8_col2, #T_9a8e2_row8_col3, #T_9a8e2_row9_col0, #T_9a8e2_row9_col1, #T_9a8e2_row9_col2, #T_9a8e2_row9_col3, #T_9a8e2_row10_col0, #T_9a8e2_row10_col1, #T_9a8e2_row10_col2, #T_9a8e2_row10_col3, #T_9a8e2_row11_col0, #T_9a8e2_row11_col1, #T_9a8e2_row11_col2, #T_9a8e2_row11_col3, #T_9a8e2_row12_col0, #T_9a8e2_row12_col1, #T_9a8e2_row12_col2, #T_9a8e2_row12_col3, #T_9a8e2_row13_col0, #T_9a8e2_row13_col1, #T_9a8e2_row13_col2, #T_9a8e2_row13_col3 {
#   background: rgba(173, 216, 230, 0.4);
#   font-size: 19px;
# }
# </style>
# <table id="T_9a8e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a8e2_level0_col0" class="col_heading level0 col0" >work_year</th>
#       <th id="T_9a8e2_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_9a8e2_level0_col2" class="col_heading level0 col2" >salary_in_usd</th>
#       <th id="T_9a8e2_level0_col3" class="col_heading level0 col3" >remote_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a8e2_level0_row0" class="row_heading level0 row0" >Mean</th>
#       <td id="T_9a8e2_row0_col0" class="data row0 col0" >2,023.83</td>
#       <td id="T_9a8e2_row0_col1" class="data row0 col1" >162,555.90</td>
#       <td id="T_9a8e2_row0_col2" class="data row0 col2" >158,014.86</td>
#       <td id="T_9a8e2_row0_col3" class="data row0 col3" >21.58</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row1" class="row_heading level0 row1" >Median</th>
#       <td id="T_9a8e2_row1_col0" class="data row1 col0" >2,024.00</td>
#       <td id="T_9a8e2_row1_col1" class="data row1 col1" >148,000.00</td>
#       <td id="T_9a8e2_row1_col2" class="data row1 col2" >147,500.00</td>
#       <td id="T_9a8e2_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row2" class="row_heading level0 row2" >Mode</th>
#       <td id="T_9a8e2_row2_col0" class="data row2 col0" >2,024.00</td>
#       <td id="T_9a8e2_row2_col1" class="data row2 col1" >160,000.00</td>
#       <td id="T_9a8e2_row2_col2" class="data row2 col2" >160,000.00</td>
#       <td id="T_9a8e2_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row3" class="row_heading level0 row3" >Range</th>
#       <td id="T_9a8e2_row3_col0" class="data row3 col0" >5.00</td>
#       <td id="T_9a8e2_row3_col1" class="data row3 col1" >30,386,000.00</td>
#       <td id="T_9a8e2_row3_col2" class="data row3 col2" >785,000.00</td>
#       <td id="T_9a8e2_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row4" class="row_heading level0 row4" >Stdev</th>
#       <td id="T_9a8e2_row4_col0" class="data row4 col0" >0.48</td>
#       <td id="T_9a8e2_row4_col1" class="data row4 col1" >192,572.92</td>
#       <td id="T_9a8e2_row4_col2" class="data row4 col2" >72,504.07</td>
#       <td id="T_9a8e2_row4_col3" class="data row4 col3" >41.02</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row5" class="row_heading level0 row5" >Variance</th>
#       <td id="T_9a8e2_row5_col0" class="data row5 col0" >0.23</td>
#       <td id="T_9a8e2_row5_col1" class="data row5 col1" >37,084,328,023.17</td>
#       <td id="T_9a8e2_row5_col2" class="data row5 col2" >5,256,839,633.69</td>
#       <td id="T_9a8e2_row5_col3" class="data row5 col3" >1,682.81</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row6" class="row_heading level0 row6" >IQR</th>
#       <td id="T_9a8e2_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_9a8e2_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_9a8e2_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_9a8e2_row6_col3" class="data row6 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row7" class="row_heading level0 row7" >25%</th>
#       <td id="T_9a8e2_row7_col0" class="data row7 col0" >2,024.00</td>
#       <td id="T_9a8e2_row7_col1" class="data row7 col1" >106,957.50</td>
#       <td id="T_9a8e2_row7_col2" class="data row7 col2" >106,890.00</td>
#       <td id="T_9a8e2_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row8" class="row_heading level0 row8" >50%</th>
#       <td id="T_9a8e2_row8_col0" class="data row8 col0" >2,024.00</td>
#       <td id="T_9a8e2_row8_col1" class="data row8 col1" >148,000.00</td>
#       <td id="T_9a8e2_row8_col2" class="data row8 col2" >147,500.00</td>
#       <td id="T_9a8e2_row8_col3" class="data row8 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row9" class="row_heading level0 row9" >75%</th>
#       <td id="T_9a8e2_row9_col0" class="data row9 col0" >2,024.00</td>
#       <td id="T_9a8e2_row9_col1" class="data row9 col1" >200,000.00</td>
#       <td id="T_9a8e2_row9_col2" class="data row9 col2" >199,700.00</td>
#       <td id="T_9a8e2_row9_col3" class="data row9 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row10" class="row_heading level0 row10" >Min</th>
#       <td id="T_9a8e2_row10_col0" class="data row10 col0" >2,020.00</td>
#       <td id="T_9a8e2_row10_col1" class="data row10 col1" >14,000.00</td>
#       <td id="T_9a8e2_row10_col2" class="data row10 col2" >15,000.00</td>
#       <td id="T_9a8e2_row10_col3" class="data row10 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row11" class="row_heading level0 row11" >Max</th>
#       <td id="T_9a8e2_row11_col0" class="data row11 col0" >2,025.00</td>
#       <td id="T_9a8e2_row11_col1" class="data row11 col1" >30,400,000.00</td>
#       <td id="T_9a8e2_row11_col2" class="data row11 col2" >800,000.00</td>
#       <td id="T_9a8e2_row11_col3" class="data row11 col3" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row12" class="row_heading level0 row12" >Skewness</th>
#       <td id="T_9a8e2_row12_col0" class="data row12 col0" >-2.92</td>
#       <td id="T_9a8e2_row12_col1" class="data row12 col1" >70.52</td>
#       <td id="T_9a8e2_row12_col2" class="data row12 col2" >1.22</td>
#       <td id="T_9a8e2_row12_col3" class="data row12 col3" >1.38</td>
#     </tr>
#     <tr>
#       <th id="T_9a8e2_level0_row13" class="row_heading level0 row13" >Kurtosis</th>
#       <td id="T_9a8e2_row13_col0" class="data row13 col0" >11.16</td>
#       <td id="T_9a8e2_row13_col1" class="data row13 col1" >9,051.86</td>
#       <td id="T_9a8e2_row13_col2" class="data row13 col2" >3.98</td>
#       <td id="T_9a8e2_row13_col3" class="data row13 col3" >-0.08</td>
#     </tr>
#   </tbody>
# </table>

# %%
def variable_summary(df, opacity=0.5, font_size='20px'):
    # Inicializa una lista vacía para almacenar los resúmenes individuales
    summaries = []

    # Itera sobre cada columna del DataFrame
    for col in df.columns:
        dtype = df[col].dtype             # Tipo de dato de la columna
        count = df[col].count()           # Conteo de valores no nulos
        unique = df[col].nunique()        # Número de valores únicos
        missing = df[col].isna().sum()    # Número de valores faltantes (nulos)

        # Agrega la información del resumen a la lista
        summaries.append([col, dtype, count, unique, missing])

    # DataFrame a partir de la lista de resúmenes
    summary_df = pd.DataFrame(summaries, columns=['Variable', 'Dtype', 'Count', 'Unique', 'Missing'])

    # Aplicar color de fondo con opacidad
    styled_summary_df = summary_df.style.apply(
        lambda x: [f'background: rgba(42, 46, 120, {opacity})' for val in x], axis=1
    )

    # tamaño de fuente a toda la tabla
    styled_summary_df.set_table_styles([{'selector': '', 'props': [('font-size', font_size)]}])

    return styled_summary_df

# %%
summary_df = variable_summary(df)
summary_df
# Out:
# <style type="text/css">
# #T_8e7b0  {
#   font-size: 20px;
# }
# #T_8e7b0_row0_col0, #T_8e7b0_row0_col1, #T_8e7b0_row0_col2, #T_8e7b0_row0_col3, #T_8e7b0_row0_col4, #T_8e7b0_row1_col0, #T_8e7b0_row1_col1, #T_8e7b0_row1_col2, #T_8e7b0_row1_col3, #T_8e7b0_row1_col4, #T_8e7b0_row2_col0, #T_8e7b0_row2_col1, #T_8e7b0_row2_col2, #T_8e7b0_row2_col3, #T_8e7b0_row2_col4, #T_8e7b0_row3_col0, #T_8e7b0_row3_col1, #T_8e7b0_row3_col2, #T_8e7b0_row3_col3, #T_8e7b0_row3_col4, #T_8e7b0_row4_col0, #T_8e7b0_row4_col1, #T_8e7b0_row4_col2, #T_8e7b0_row4_col3, #T_8e7b0_row4_col4, #T_8e7b0_row5_col0, #T_8e7b0_row5_col1, #T_8e7b0_row5_col2, #T_8e7b0_row5_col3, #T_8e7b0_row5_col4, #T_8e7b0_row6_col0, #T_8e7b0_row6_col1, #T_8e7b0_row6_col2, #T_8e7b0_row6_col3, #T_8e7b0_row6_col4, #T_8e7b0_row7_col0, #T_8e7b0_row7_col1, #T_8e7b0_row7_col2, #T_8e7b0_row7_col3, #T_8e7b0_row7_col4, #T_8e7b0_row8_col0, #T_8e7b0_row8_col1, #T_8e7b0_row8_col2, #T_8e7b0_row8_col3, #T_8e7b0_row8_col4, #T_8e7b0_row9_col0, #T_8e7b0_row9_col1, #T_8e7b0_row9_col2, #T_8e7b0_row9_col3, #T_8e7b0_row9_col4, #T_8e7b0_row10_col0, #T_8e7b0_row10_col1, #T_8e7b0_row10_col2, #T_8e7b0_row10_col3, #T_8e7b0_row10_col4 {
#   background: rgba(42, 46, 120, 0.5);
# }
# </style>
# <table id="T_8e7b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e7b0_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_8e7b0_level0_col1" class="col_heading level0 col1" >Dtype</th>
#       <th id="T_8e7b0_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_8e7b0_level0_col3" class="col_heading level0 col3" >Unique</th>
#       <th id="T_8e7b0_level0_col4" class="col_heading level0 col4" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e7b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e7b0_row0_col0" class="data row0 col0" >work_year</td>
#       <td id="T_8e7b0_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_8e7b0_row0_col2" class="data row0 col2" >73155</td>
#       <td id="T_8e7b0_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_8e7b0_row0_col4" class="data row0 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e7b0_row1_col0" class="data row1 col0" >experience_level</td>
#       <td id="T_8e7b0_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_8e7b0_row1_col2" class="data row1 col2" >73155</td>
#       <td id="T_8e7b0_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_8e7b0_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e7b0_row2_col0" class="data row2 col0" >employment_type</td>
#       <td id="T_8e7b0_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_8e7b0_row2_col2" class="data row2 col2" >73155</td>
#       <td id="T_8e7b0_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_8e7b0_row2_col4" class="data row2 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e7b0_row3_col0" class="data row3 col0" >job_title</td>
#       <td id="T_8e7b0_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_8e7b0_row3_col2" class="data row3 col2" >73150</td>
#       <td id="T_8e7b0_row3_col3" class="data row3 col3" >289</td>
#       <td id="T_8e7b0_row3_col4" class="data row3 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e7b0_row4_col0" class="data row4 col0" >salary</td>
#       <td id="T_8e7b0_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_8e7b0_row4_col2" class="data row4 col2" >73152</td>
#       <td id="T_8e7b0_row4_col3" class="data row4 col3" >7096</td>
#       <td id="T_8e7b0_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e7b0_row5_col0" class="data row5 col0" >salary_currency</td>
#       <td id="T_8e7b0_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_8e7b0_row5_col2" class="data row5 col2" >73153</td>
#       <td id="T_8e7b0_row5_col3" class="data row5 col3" >25</td>
#       <td id="T_8e7b0_row5_col4" class="data row5 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8e7b0_row6_col0" class="data row6 col0" >salary_in_usd</td>
#       <td id="T_8e7b0_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_8e7b0_row6_col2" class="data row6 col2" >73152</td>
#       <td id="T_8e7b0_row6_col3" class="data row6 col3" >7702</td>
#       <td id="T_8e7b0_row6_col4" class="data row6 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8e7b0_row7_col0" class="data row7 col0" >employee_residence</td>
#       <td id="T_8e7b0_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_8e7b0_row7_col2" class="data row7 col2" >73155</td>
#       <td id="T_8e7b0_row7_col3" class="data row7 col3" >93</td>
#       <td id="T_8e7b0_row7_col4" class="data row7 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8e7b0_row8_col0" class="data row8 col0" >remote_ratio</td>
#       <td id="T_8e7b0_row8_col1" class="data row8 col1" >float64</td>
#       <td id="T_8e7b0_row8_col2" class="data row8 col2" >73153</td>
#       <td id="T_8e7b0_row8_col3" class="data row8 col3" >3</td>
#       <td id="T_8e7b0_row8_col4" class="data row8 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8e7b0_row9_col0" class="data row9 col0" >company_location</td>
#       <td id="T_8e7b0_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_8e7b0_row9_col2" class="data row9 col2" >73155</td>
#       <td id="T_8e7b0_row9_col3" class="data row9 col3" >86</td>
#       <td id="T_8e7b0_row9_col4" class="data row9 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e7b0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8e7b0_row10_col0" class="data row10 col0" >company_size</td>
#       <td id="T_8e7b0_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_8e7b0_row10_col2" class="data row10 col2" >73155</td>
#       <td id="T_8e7b0_row10_col3" class="data row10 col3" >4</td>
#       <td id="T_8e7b0_row10_col4" class="data row10 col4" >12</td>
#     </tr>
#   </tbody>
# </table>
